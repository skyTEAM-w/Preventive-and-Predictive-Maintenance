# %%
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import os
import sys

# %%
data = sio.loadmat('../data/input/CWRU/12k Drive End Bearing Fault Data/105.mat')
data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Mon Jan 31 13:49:59 2000',
#  '__version__': '1.0',
#  '__globals__': [],
#  'X105_DE_time': array([[-0.08300435],
#         [-0.19573433],
#         [ 0.23341928],
#         ...,
#         [-0.31642363],
#         [-0.06367457],
#         [ 0.26736822]]),
#  'X105_FE_time': array([[-0.40207455],
#         [-0.00472545],
#         [-0.10663091],
#         ...,
#         [ 0.31598909],
#         [ 0.35091636],
#         [ 0.03307818]]),
#  'X105_BA_time': array([[ 0.06466148],
#         [-0.02309626],
#         [-0.08852226],
#         ...,
#         [ 0.09648926],
#         [ 0.08405591],
#         [-0.02015893]]),
#  'X105RPM': array([[1797]], dtype=uint16)}

# %%
# Out:
# numpy.ndarray

# %%
data_y = np.array(data['X105_FE_time'])
data_y
# Out:
# array([[1797]], dtype=uint16)

# %%
plt.plot(data_y)

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X105_DE_time', 'X105_FE_time', 'X105_BA_time', 'X105RPM'])
